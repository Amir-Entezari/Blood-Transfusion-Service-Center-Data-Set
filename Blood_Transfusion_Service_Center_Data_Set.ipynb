# %% [markdown]
# <a href="https://colab.research.google.com/github/Amir-Entezari/Blood-Transfusion-Service-Center-Data-Set/blob/main/Blood_Transfusion_Service_Center_Data_Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/blood-transfusion/transfusion.data")
#-------USE THE ABOVE LINE IF LINK DOESNT WORKS FOR YOU-------
#df = pd.read_csv("transfusion.data")
df_log2=data=pd.read_csv("transfusion.data")
df_log10=data =pd.read_csv("transfusion.data")
df_pow2=data =pd.read_csv("transfusion.data")
df_log10_pow2=data =pd.read_csv("transfusion.data")
df_column = ["Recency (months)","Frequency (times)","Monetary (c.c. blood)","Time (months)","whether he/she donated blood in March 2007"]

# %% [markdown]
# # <center>1.Box Plot

# %% [markdown]
# ### 1.1 Single Box plot
# #### در شکل زیر نمودار های جعبه ای به صورت تکی نمایش داده شده اند.

# %%
plt.boxplot(x='Recency (months)',data=df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a297307cd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a2972e8430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a297307940>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a2972e8b50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a2972e8ee0>],
#  'means': []}

# %%
plt.boxplot(x='Frequency (times)',data=df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a297c7fb20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a297c8b280>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a297c7f790>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a297c8b9a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a297c8bd30>],
#  'means': []}

# %%
plt.boxplot(x='Monetary (c.c. blood)',data=df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a297cea190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a297cea8b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a297cdbd90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a297ceafd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a297cf53a0>],
#  'means': []}

# %%
plt.boxplot(x='Time (months)',data=df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a297d501c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a297d508e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a297d41dc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a297d5b040>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a297d5b3d0>],
#  'means': []}

# %%
plt.boxplot(x='whether he/she donated blood in March 2007',data=df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a297da9e80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a297db5610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a297da9af0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a297db5d30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a297dc4100>],
#  'means': []}

# %% [markdown]
# ### 1.2 All Box Plots
# #### حال نمودار جعبه ای را برای تمام ستون های دیتا فریم رسم میکنیم. همانطور که مشاهده میکنیم نمودار جعبه ای برای ستون ها (بجز ستون 3) بسیار متراکم دیده میشود که بدلیل تفاوت واحد های هر یک از ستون ها می باشد.
# #### براساس توضیحات سرکلاس و کتاب ، نمودار فریکوئنسی نسبت به بقیه نمودار ها بهتر است چرا که در بقیه نمودار ها داده پرت بسیار است

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.boxenplot(data=data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # <center>1.Scatter Plot</center>

# %% [markdown]
# ### 2.1 Single Scatter Plot
# #### در شکل زیر یک نمونه از نمودار نقطه ای برای ستون دوم دیتا فریم را مشاهده میکنیم

# %%
df.plot.scatter(x='Frequency (times)', y='Time (months)')
# Out:
# <AxesSubplot:xlabel='Frequency (times)', ylabel='Time (months)'>

# %% [markdown]
# ### 2.2 All Scatter Plots
# #### حال اگر نمودار را برای تمام ستون ها رسم کنیم به شکل زیر میرسیم.<br>نمودار هایی که پراکندگی بیشتری دارند نمودار های بهتری هستند(چرا که فاصله بیشتری دارند و در نتیجه شباهت آن ها کمتر است)

# %%
sns.pairplot(df,hue=df_column[4])

# %% [markdown]
# #### در عملیات تبدیل داده ها از یک تابع استفاده می شود که مجموعه کل را مقادیر یک ویژگی مفروض را به یک مجموعه جدیدی از مقادیر نگاشت میکند. این کار به گونه ای انجام می شود که هر یک از مقادیر قدیمی بتواند با یکی از مقادر جدید شناسایی شود. به عنوان مثال تعدادی از توابع تبدیل عباتند از+قدر مطلق-توان-لگاریتمو ...
# *منبع: کتاب داده کاوی کاربردی

# %% [markdown]
# #### حال در شکل زیر نمودار را براساس لگاریتم دو تبدیل میکنیم تا دید بهتری نسبت به داده ها به ما بدهد.

# %%
for x in range(4):
    df_log2[df_column[x]+'_log2']= np.log2(df[df_column[x]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.pairplot(df_log2,hue=df_column[4])

# %% [markdown]
# #### همانطور که در شکل دیده میشود با به لگاریتم 2 رساندن نیز داده ها به خوبی از یک دیگر جدا نمیشوند. اینکار را برای لگاریتم 10 نیز امتحان میکنیم بلکه تصویر بهتری بگیریم

# %%
for x in range(4):
    df_log10[df_column[x]+'_log10']= np.log10(df[df_column[x]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.pairplot(df_log10,hue=df_column[4])

# %% [markdown]
# #### باز هم در این تصویر نمیتوان به خوبی داده ها را جدا کرد اما به نسب میتوان بیان که که نمودار های تایم و مانتری وضع بهتری دارند
# #### همچنین درنمودار های فرکانس و مانتری پخش داده ها نیز بیشتر بوده است

# %% [markdown]
# #### اکنون داده ها را به توان دو نیز میرسانیم تا تا به مقایسه بهتری دست یابیم

# %%
for x in range(4):    
    df_pow2[df_column[x]+'_pow2']= np.power(df[df_column[x]],2)

# %%
sns.pairplot(df_pow2,hue=df_column[4],)

# %% [markdown]
# #### در این حالت نیز مشاهده میشود که نمودار مانتری نسبت به بقیه پخش بیشتری صورت گرفته است

# %% [markdown]
# #### حال برای بار اخر ترکیبی از تبدیل های قبل را بکار میگیریم

# %%
for x in range(4):    
    df_log10_pow2[df_column[x]+'pow2']= np.power(df[df_column[x]],2)
for x in range(4):    
    df_log10_pow2[df_column[x]+'_log10']= np.log10(df[df_column[x]])

# %%
sns.pairplot(df_log8_pow2,hue=df_column[4])

# %% [markdown]
# #### پس از ترکیب دو تبدیل نیز به این نتیجه میرسیم مانتری و تایم وضع بهتری نسبت به سایر نمودار ها دارند

# %% [markdown]
# #### به طور کلی در نمودار اسکتر ما تمایل داریم هر رکورد را به صورت یک نقطه در فضای چند بعدی نمایش دهیم. اما وقتی ابعاد زیادتر شود، نمایش رکورد ها و درک آن ها برای ما سخت تر خواهد شد. در نمودار های پراکندگی 2 بعدی کل رکورد ها براساس دو ویژگی رسم میشوند. برای این منظور تمام ویژگی های مورد نظر را جفت جفت در نظر میگریم و برای هر حالت کل رکورد هارا بر اساس دو ویژگی در نظر گرفته شده رسم میکنیم. مقادیر ویژگی ها،موقعیت ها و مکان هارا مشخص می کند. از این رو هر چه پراکندگی بیشتر باشد شباههت و کمتر و نمودار بهتری است
